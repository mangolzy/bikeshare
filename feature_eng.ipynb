# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %%
time_feature = pd.read_csv("ouput/20DRY-DS")
time_feature.head(3)
# Out:
#               datetime  number
# 0  2014-07-10 08:00:00       1
# 1  2014-07-12 04:00:00       1
# 2  2014-07-16 12:00:00       1

# %%
update = lambda x: x[0:10]
time_feature['time'] = time_feature['datetime'].map(update)

# %%
time_feature.head(3)
# Out:
#               datetime  number        time
# 0  2014-07-10 08:00:00       1  2014-07-10
# 1  2014-07-12 04:00:00       1  2014-07-12
# 2  2014-07-16 12:00:00       1  2014-07-16

# %%
x = time_feature.groupby('time').sum()

# %%
formatter = '%Y-%m-%d'

def datetime_complete(df):
  "complement the missing time units with zero value"
  global formatter
  data = []
  previousDatetime = None
  c = None
  for number, currentDatetime in df.itertuples(index = False):
    c = datetime.datetime.strptime(currentDatetime, formatter)
    if (previousDatetime != None):
      p = datetime.datetime.strptime(previousDatetime, formatter)
      complementZero(data, p, c)
    previousDatetime = currentDatetime
    data.append([currentDatetime, number])
  res = pd.DataFrame(data)
  res.columns = df.columns.values
  return res

def complementZero(data, start, end):
  global formatter
  delta = int((end - start).total_seconds() // 86400)
  if (delta > 1):
    for i in range(1, delta):
      start = start + datetime.timedelta(days = 1)
      data.append([start.strftime(formatter), 0])

# %%
c = datetime_complete(x)
c.head(3)

# %%
month_7 = c[0:22]
month_8 = c[22:53]
month_9 = c[53:83]
month_10 = c[83:114]
month_11 = c[114:144]
month_12 = c[144:175]
month_1 = c[175:206]
month_2 = c[206:234]
month_3 = c[234:265]

# %%
fig = plt.figure(figsize=(18, 6), dpi = 1600)
plt.scatter(range(22), month_7['datetime'])
plt.title("The Count of Container's Rental on 2014/07")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")
#plt.hold(True)
#plt.plot(range(408), train['number'])

# %%
fig = plt.figure(figsize=(18, 6), dpi = 1600)
plt.scatter(range(31), month_8['datetime'])
plt.title("The Count of Container's Rental on 2014/07")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

# %%
fig = plt.figure(figsize=(18, 6), dpi = 1600)
plt.scatter(range(30), month_9['datetime'])
plt.title("The Count of Container's Rental on 2014/09")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

# %%
fig = plt.figure(figsize=(18, 6), dpi = 1600)
ax1 = plt.subplot2grid((2,3),(0,0))
plt.scatter(range(31), month_10['datetime'])
plt.title("The Count of Container's Rental on 2014/10")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

plt.subplot2grid((2,3),(0,1))
plt.scatter(range(30), month_11['datetime'])
plt.title("The Count of Container's Rental on 2014/11")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

plt.subplot2grid((2,3),(0,2))
plt.scatter(range(31), month_12['datetime'])
plt.title("The Count of Container's Rental on 2014/12")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

plt.subplot2grid((2,3),(1,0))
plt.scatter(range(31), month_1['datetime'])
plt.title("The Count of Container's Rental on 2015/01")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

plt.subplot2grid((2,3),(1,1))
plt.scatter(range(28), month_2['datetime'])
plt.title("The Count of Container's Rental on 2015/02")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

plt.subplot2grid((2,3),(1,2))
plt.scatter(range(31), month_3['datetime'])
plt.title("The Count of Container's Rental on 2015/03")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of Container rental every day")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.api import qqplot
from scipy import stats

# %matplotlib inline

# %%
train = pd.read_csv('sample.csv', header = 0)
add = pd.read_csv('final2.csv', header = 0)

# %%
train.shape
# Out:
# (408, 2)

# %%
res = train['count']
res = res.append(add['x'] * 1.5)

# %%
res.shape
# Out:
# (247,)

# %%
fig = plt.figure(figsize=(18, 6), dpi = 1600)
plt.plot(range(432), add['number'])
plt.title("The Forecast on bicycle rental based on Random Forest")
plt.xlabel("DateTime on the DataSet")
plt.ylabel("Account of bicycle rental per hour")
plt.hold(True)
plt.plot(range(408), train['number'])

# %%
train['count.1'].tail(3)
# Out:
# 196    59.053846
# 197    55.351852
# 198    31.529412
# Name: count.1, dtype: float64

# %%
extra = [0,5,8.6,10,14.2,15, 15.5,15.8,17,22,25, 30,38,46,80,90, 120,150,150,150,150, 130,130,130,100,80, 40,20,10,15,16, 14,30,48,50,52, 58,62,90,110,120, 120,120,130,130,130, 80,50]

# %%
extra = map((lambda x: x+30), extra)
extra = np.transpose(extra)

# %%
ori = train['count.1']

# %%
extra = pd.DataFrame(extra)

# %%
ori = ori.append(extra)
